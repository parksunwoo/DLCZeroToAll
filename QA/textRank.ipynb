# %%
# !pip3 install networkx
# Out:
# Requirement already satisfied: networkx in /anaconda3/lib/python3.6/site-packages (1.11)
# Requirement already satisfied: decorator>=3.4.0 in /anaconda3/lib/python3.6/site-packages (from networkx) (4.2.1)

# %% [markdown]
# # textrank 사용 문장요약
# ## 1st textrank_korean

# %% [markdown]
# * window : 문맥으로 사용할 단어의 개수. 기본값 5로 주면 특정 단어의 좌우 5개씩, 총 10개 단어를 문맥으로 사용합니다.
#
# * coef : 동시출현 빈도를 weight에 반영하는 비율입니다. 기본값은 1.0로, 동시출현 빈도를 weight에 전부 반영합니다. 0.0일 경우 빈도를 반영하지 않고 모든 간선의 weight을 1로 동일하게 간주합니다.
#
# * threshold: 문서 요약시 관련있는 문장으로 여길 최소 유사도값. 기본값은 0.005이고, 이 값보다 작은 유사도를 가지는 문장쌍은 관련없는문장으로 처리합니다.

# %%
import networkx
import re
 
class RawSentence:
    def __init__(self, textIter):
        if type(textIter) == str: self.textIter = textIter.split('\n')
        else: self.textIter = textIter
        self.rgxSplitter = re.compile('([.!?:](?:["\']|(?![0-9])))')
 
    def __iter__(self):
        for line in self.textIter:
            ch = self.rgxSplitter.split(line)
            for s in map(lambda a, b: a + b, ch[::2], ch[1::2]):
                if not s: continue
                yield s
 
class RawSentenceReader:
    def __init__(self, filepath):
        self.filepath = filepath
        self.rgxSplitter = re.compile('([.!?:](?:["\']|(?![0-9])))')
 
    def __iter__(self):
        for line in open(self.filepath, encoding='utf-8'):
            ch = self.rgxSplitter.split(line)
            for s in map(lambda a, b: a + b, ch[::2], ch[1::2]):
                if not s: continue
                yield s
 
class RawTagger:
    def __init__(self, textIter, tagger = None):
        if tagger:
            self.tagger = tagger
        else :
            from konlpy.tag import Komoran
            self.tagger = Komoran()
        if type(textIter) == str: self.textIter = textIter.split('\n')
        else: self.textIter = textIter
        self.rgxSplitter = re.compile('([.!?:](?:["\']|(?![0-9])))')
 
    def __iter__(self):
        for line in self.textIter:
            ch = self.rgxSplitter.split(line)
            for s in map(lambda a,b:a+b, ch[::2], ch[1::2]):
                if not s: continue
                yield self.tagger.pos(s)
 
class RawTaggerReader:
    def __init__(self, filepath, tagger = None):
        if tagger:
            self.tagger = tagger
        else :
            from konlpy.tag import Komoran
            self.tagger = Komoran()
        self.filepath = filepath
        self.rgxSplitter = re.compile('([.!?:](?:["\']|(?![0-9])))')
 
    def __iter__(self):
        for line in open(self.filepath, encoding='utf-8'):
            ch = self.rgxSplitter.split(line)
            for s in map(lambda a,b:a+b, ch[::2], ch[1::2]):
                if not s: continue
                yield self.tagger.pos(s)
 
class TextRank:
    def __init__(self, **kargs):
        self.graph = None
        self.window = kargs.get('window', 5)
        self.coef = kargs.get('coef', 1.0)
        self.threshold = kargs.get('threshold', 0.005)
        self.dictCount = {}
        self.dictBiCount = {}
        self.dictNear = {}
        self.nTotal = 0
 
 
    def load(self, sentenceIter, wordFilter = None):
        def insertPair(a, b):
            if a > b: a, b = b, a
            elif a == b: return
            self.dictBiCount[a, b] = self.dictBiCount.get((a, b), 0) + 1
 
        def insertNearPair(a, b):
            self.dictNear[a, b] = self.dictNear.get((a, b), 0) + 1
 
        for sent in sentenceIter:
            for i, word in enumerate(sent):
                if wordFilter and not wordFilter(word): continue
                self.dictCount[word] = self.dictCount.get(word, 0) + 1
                self.nTotal += 1
                if i - 1 >= 0 and (not wordFilter or wordFilter(sent[i-1])): insertNearPair(sent[i-1], word)
                if i + 1 < len(sent) and (not wordFilter or wordFilter(sent[i+1])): insertNearPair(word, sent[i+1])
                for j in range(i+1, min(i+self.window+1, len(sent))):
                    if wordFilter and not wordFilter(sent[j]): continue
                    if sent[j] != word: insertPair(word, sent[j])
 
    def loadSents(self, sentenceIter, tokenizer = None):
        import math
        def similarity(a, b):
            n = len(a.intersection(b))
            return n / float(len(a) + len(b) - n) / (math.log(len(a)+1) * math.log(len(b)+1))
 
        if not tokenizer: rgxSplitter = re.compile('[\\s.,:;-?!()"\']+')
        sentSet = []
        for sent in filter(None, sentenceIter):
            if type(sent) == str:
                if tokenizer: s = set(filter(None, tokenizer(sent)))
                else: s = set(filter(None, rgxSplitter.split(sent)))
            else: s = set(sent)
            if len(s) < 2: continue
            self.dictCount[len(self.dictCount)] = sent
            sentSet.append(s)
 
        for i in range(len(self.dictCount)):
            for j in range(i+1, len(self.dictCount)):
                s = similarity(sentSet[i], sentSet[j])
                if s < self.threshold: continue
                self.dictBiCount[i, j] = s
 
    def getPMI(self, a, b):
        import math
        co = self.dictNear.get((a, b), 0)
        if not co: return None
        return math.log(float(co) * self.nTotal / self.dictCount[a] / self.dictCount[b])
 
    def getI(self, a):
        import math
        if a not in self.dictCount: return None
        return math.log(self.nTotal / self.dictCount[a])
 
    def build(self):
        self.graph = networkx.Graph()
        self.graph.add_nodes_from(self.dictCount.keys())
        for (a, b), n in self.dictBiCount.items():
            self.graph.add_edge(a, b, weight=n*self.coef + (1-self.coef))
 
    def rank(self):
        return networkx.pagerank(self.graph, weight='weight')
 
    def extract(self, ratio = 0.1):
        ranks = self.rank()
        cand = sorted(ranks, key=ranks.get, reverse=True)[:int(len(ranks) * ratio)]
        pairness = {}
        startOf = {}
        tuples = {}
        for k in cand:
            tuples[(k,)] = self.getI(k) * ranks[k]
            for l in cand:
                if k == l: continue
                pmi = self.getPMI(k, l)
                if pmi: pairness[k, l] = pmi
 
        for (k, l) in sorted(pairness, key=pairness.get, reverse=True):
            print(k[0], l[0], pairness[k, l])
            if k not in startOf: startOf[k] = (k, l)
 
        for (k, l), v in pairness.items():
            pmis = v
            rs = ranks[k] * ranks[l]
            path = (k, l)
            tuples[path] = pmis / (len(path) - 1) * rs ** (1 / len(path)) * len(path)
            last = l
            while last in startOf and len(path) < 7:
                if last in path: break
                pmis += pairness[startOf[last]]
                last = startOf[last][1]
                rs *= ranks[last]
                path += (last,)
                tuples[path] = pmis / (len(path) - 1) * rs ** (1 / len(path)) * len(path)
 
        used = set()
        both = {}
        for k in sorted(tuples, key=tuples.get, reverse=True):
            if used.intersection(set(k)): continue
            both[k] = tuples[k]
            for w in k: used.add(w)
 
        #for k in cand:
        #    if k not in used or True: both[k] = ranks[k] * self.getI(k)
 
        return both
 
    def summarize(self, ratio = 0.333):
        r = self.rank()
        ks = sorted(r, key=r.get, reverse=True)[:int(len(r)*ratio)]
        return ' '.join(map(lambda k:self.dictCount[k], sorted(ks)))


##출처: https://bab2min.tistory.com/570 [나의 큰 O는 logx야..]

# %%
tr = TextRank()
print('Load...')
from konlpy.tag import Komoran
tagger = Komoran()
stopword = set([('있', 'VV'), ('하', 'VV'), ('되', 'VV') ])
tr.loadSents(RawSentenceReader('wiki/chosun.txt'), lambda sent: filter(lambda x:x not in stopword and x[1] in ('NNG', 'NNP', 'VV', 'VA'), tagger.pos(sent)))
print('Build...')
tr.build()
ranks = tr.rank()
for k in sorted(ranks, key=ranks.get, reverse=True)[:100]:
    print("\t".join([str(k), str(ranks[k]), str(tr.dictCount[k])]))
print(tr.summarize(0.2))
# Out:
# Load...
# Build...
# 0	0.011207935010104895	조선(朝鮮, 중세 한국어:
# 86	0.009366288421498281	 이 두 정책은 조선의 근본정책으로서 계속 계승되었다.
# 332	0.009113452185489009	 그런데 일본도 조선을 한국이라 부른 면도 있다.
# 284	0.00873013761167629	 일본은 이러한 무력을 배경으로 조선에게 개항을 강요하였다.
# 1	0.008387459623360849	 리조조선, 리씨조선, 약칭:
# 272	0.007881835827510236	이로부터 5년 뒤, 이번에는 미국이 조선을 침략하였다.
# 84	0.007478918075117014	 조선 국왕을 정식 국왕으로 승인한 것은 1401년(태종 1년) 태종 때였다.
# 34	0.007200455936494347	 또한 무능한 개혁 정책은 조선을 근본적인 근대화로 이끌지 못했다.
# 331	0.006486347111230253	 하지만 일본 등의 나라는 조선의 황제국 선포를 인정하지 않고 조선이라 불렀다.
# 204	0.006129112936612273	이 부분의 본문은 붕당입니다.
# 51	0.006110011273139255	 성종(재위 1469~94년)은 개국 이후의 문물제도를 정비하였다.
# 269	0.006093657593393048	 프랑스는 조선에 대해 사과와 손해 배상, 그리고 통상을 요구하였다.
# 12	0.006065652893776164	 성종은 개국 이후의 문물 제도를 정비했다.
# 154	0.0060157905387051	1592년, 일본을 통일한 도요토미 히데요시(풍신수길)는 20만 병력의 일본군을 조선에 대거 보내어 조선을 침략했다.
# 40	0.006012197653121029	 흔히 조선(朝鮮) 또는 조선 왕조(朝鮮王朝), 이씨 조선(李氏朝鮮), 이왕조(李王朝), 이조(李朝)라고 부르기도 하였다.
# 107	0.005962680472387903	15세기 말부터 지방의 사림 세력이 정계에서 세력을 키우기 시작했다.
# 13	0.005962680472387902	 15세기 말부터 지방의 사림 세력이 정계에서 세력을 키우기 시작했다.
# 52	0.005962680472387902	 15세기 말부터 지방의 사림 세력이 정계에서 세력을 키우기 시작했다.
# 16	0.005957861224841792	 이후 사림들은 '붕당'을 형성하여 조선 정치의 꽃이자 역모 반란죄에 해당될 수 있는 붕당정치를 시행한다.
# 35	0.005937896577763873	1890년대에는 농민 수탈에 대한 저항으로 동학농민운동이 일어났고, 동학농민운동의 진압을 명분으로 조선에 들어온 청나라와 일본의 군대가 충돌하기도 했다.
# 321	0.0057159529687772805	러시아와 독일, 프랑스의 삼국간섭을 받은 일본은 요동 반도를 잃었고, 남하하는 러시아는 조선에 큰 영향력을 지니게 되었다.
# 23	0.005608705738857219	1680년의 경신환국으로 서인이 권력을 잡은 뒤 균형이 무너져, 서인은 남인을 철저히 탄압하였다.
# 48	0.0055827464940432425	 태종 이방원(재위 1400~18년)은 왕권을 강화하고 임금 중심의 통치 체제를 정비하기 위해 관료 제도를 정비했다.
# 7	0.005562357540455099	[5] 1393년 2월 15일에는 국명을 “조선(朝鮮)”으로 정하였고[6], 1394년에는 한양을 도읍으로 하여 여러 개혁을 단행했다.
# 115	0.005399600778058245	 그 이후 사림들 간 자기 일파(일당 전제화)만이 정권을 장악하기 위하여 대대로 대립하니, 이를 당쟁이라 한다.
# 239	0.005392760656004755	정조의 갑작스러운 죽음과 세도정치의 시작은 조선사회 쇠락의 가장 큰 원인이 되었다.
# 41	0.00535995851414968	조선(1392~1897)의 역사는 크게 전기와 후기로 나누며, 전기를 다시 둘로 나눠 전기와 중기로 보아 전기-중기-후기로 보기도 한다.
# 187	0.005355127242198896	 1890년대에는 농민 수탈에 대한 저항으로 동학농민운동이 일어났고, 동학농민운동의 진압을 명분으로 조선에 들어온 청나라와 일본의 군대가 충돌하였고, 친일적인 갑오개혁이 있었다.
# 210	0.00534854792512972	남인들은 서인 정권이 추구한 개혁의 부당성과 북벌 운동의 무모함을 지적하면서 예송논쟁(禮訟論爭)을 일으켜 서인들과 정치적으로 대립하였다.
# 282	0.005341275037372394	 이에 따라 자연스레 통상 개화론자들이 대두되면서 조선의 대외정책은 조금씩 변하기 시작했다.
# 19	0.005282108035659131	조선 후기의 정치는 붕당을 중심으로 형성되었다.
# 177	0.005205735685372566	조선 후기의 정치는 붕당을 중심으로 형성되었는데 마침내 서인은 17세기 중반의 예송논쟁에서 남인에게 권력을 넘겨준다.
# 82	0.005161170546937023	 개국 초기 정도전의 요동정벌 문제로 명나라는 조선의 국왕을 인정하지 않았다.
# 185	0.005135863974374276	 이어 일본, 미국 등에 문호를 개방하였다.
# 102	0.005122452373831824	세조의 손자인 성종은 개국 이후의 문물제도를 정비하였다.
# 208	0.005037391308474785	 서인이 주도하는 정국에서도 남인은 꾸준히 진출하였다.
# 128	0.0050181273109905925	 선조는 사림을 통해 자신의 취약한 권력 기반을 강화하고자 하였다.
# 196	0.004972829331787846	현종과 숙종은 서인(산림, 山林)을 잠시 배척하기도 했으나 결국 남인을 몰아내고 서인과 정치를 하였다.
# 91	0.0049510298819418	 또한, 지금의 8도 정책도 태종 때부터 자리 잡은 정책이다.
# 15	0.0049491997933888915	 선조 때에는 마침내 훈구파들이 정계에서 물러나고 사림들이 정계를 장악하게 되었다.
# 203	0.00494379918503698	 이에 따라 조선에서는 청나라를 무조건 배척하지만 말고 이로운 것은 적극적으로 배우자는 북학론(北學論)이 대두하였다.
# 155	0.004941653267270766	 조선은 초반 제승방략체제가 제대로 발휘되지 못하였고, 일본군의 신무기인 조총에 크게 고전하였다.
# 153	0.004861877128264599	이 부분의 본문은 임진왜란 및 정유재란입니다.
# 243	0.004812236623409435	 이는 선조 이후 오랫동안 조선 정치권력의 기본 구조였던 붕당정치가 완전히 붕괴되었음을 의미하는 것이기도 하였다.
# 77	0.0048077052315961075	 특히 국호를 정하는 일에서도 내부적으로 국호를 정했으나, 명과의 관계를 고려하여 화령(和寧)과 조선(朝鮮) 중에서 승인을 받았던 일이 있다.
# 45	0.004776003409596503	1393년에는 국명을 명으로부터 선택받아 조선으로 고치고 1394년에는 개경의 민심이 안 좋아 한양으로 천도하여 여러 개혁을 단행했다.
# 215	0.004685827424216727	그러나 경신환국에 의하여 1680년 남인이 실각하고 서인 정권이 다시 수립되면서 붕당 사이의 대립양상은 크게 달라져 갔다.
# 217	0.0046652560453892345	 이때, 서인은 아예 남인을 완전히 축출하자는 노론과 남인과의 화해를 주장하는 소론으로 분열되었으며, 두 세력 사이의 대립으로 정국의 반전이 거듭되었다.
# 29	0.004652312244831295	고종의 아버지인 흥선대원군은 막강한 권력을 행사했다.
# 296	0.004585020709774741	이 부분의 본문은 임오군란 및 갑신정변입니다.
# 179	0.004581609528634683	 이어 서인에서 분열된 노론과 소론이 격렬하게 대립하였다.
# 286	0.004566813340938643	 이로써, 통상수교 거부정책을 써오던 조선은 부산, 인천, 원산항을 개항하게 되었다.
# 85	0.0045481935699244755	또 다른 주변 국가인 일본과 여진에게는 교린 정책(交鄰政策)을 취했다.
# 111	0.0045293059512421	 이때부터 사림은 동인과 서인으로 나뉘어 붕당정치가 시작되었다.
# 207	0.004527280454107746	 서인 정권의 위기는 겉으로는 남인 측의 도전으로부터 비롯되었다.
# 28	0.004517996176235708	 그리고 풍양 조씨의 가문의 대표였던 조대비)가 흥선대원군과 결탁하여 흥선대원군의 둘째아들 명복(고종)을 조선 국왕 자리에 올린다.
# 110	0.004483185464909239	 선조 때 비로소 훈구파를 몰아내고 조정의 실권을 잡았다.
# 124	0.004479844745025648	1545년, 명종이 조선 13대 임금으로 등극하자 어머니 문정왕후가 대왕대비로서 수렴청정했다.
# 289	0.004478232436735633	 뒤이어 일본에 신사유람단을, 청나라에 영선사를 파견하였다.
# 184	0.004476594247412789	 1873년 흥선대원군이 실각하고 여흥 민씨 정권이 들어서면서 대외정책이 개방되었다.
# 318	0.0044375393557928265	청일 전쟁에서 승리한 일본은 조선을 청나라로부터 독립시키고, 요동반도를 할양받아 만주 침략의 발판을 마련하였다(→시모노세키 조약).
# 305	0.004429372967404577	 한일 관계#갑오개혁 문서를 참고하십시오.
# 87	0.004341701152473621	두 차례에 걸친 왕자의 난에서 승리해서 왕위에 오른 태종은 왕권을 강화하고 임금 중심의 통치 체제를 정비하기 위해 관료 제도를 정비했다.
# 201	0.00433940372642454	 그러나 외부 세계와의 고립을 초래하여 조선 사회의 낙후를 가속하였다.
# 49	0.004288778105357846	세종대왕(재위 1418~1450년)은 학문 · 군사 · 과학 · 문화 등 모든 면에서 큰 업적을 이룩하였고 정치는 안정되어갔다.
# 81	0.00420312570573519	조선에서는 매년 명나라에 진하사, 문안사, 동지사 등을 보냈고 태종 때부터 선조 때까지는 종계변무사를 파견했다.
# 101	0.004201873950586	 세조는 태종처럼 신하의 권력(신권)을 제한하고, 왕권을 강화하기 위해 호패법을 다시 복원하고, 《동국통감》,《국조보감》등을 만들기도 했다.
# 216	0.004193453914278102	 즉 다시 집권한 서인은 철저한 탄압으로 남인의 재기를 막았다.
# 50	0.004146120792118916	 세조(재위 1455~68년)는 태종처럼 신하의 권력(신권)을 제한하고, 왕권을 강화하기 위해 호패법을 다시 복원하고, 《동국통감》, 《국조보감》 등을 만들기도 하였다.
# 285	0.004124135324343615	 이에 대해 조선에서는 찬반 양론이 엇갈렸으나 결국 개항 찬성론자들의 입지가 강화되어 1876년 2월 27일(음력 2월 3일) 일본과 강화도 조약을 체결하여 문호를 개방하였다.
# 236	0.004099370202473701	또한, 규장각을 붕당의 비대화를 막고 임금의 권력과 정책을 뒷받침할 수 있는 강력한 정치 기구로 육성하였다.
# 297	0.004076513333818438	 한일 관계#임오군란과 갑신정변 문서를 참고하십시오.
# 59	0.004061390780106658	이성계는 회군으로 수도 개경에 있는 모든 정권을 잡아 최영 세력을 숙청하고 우왕을 “신돈의 아들이다.
# 65	0.004055966408333443	1392년에는 이성계의 5남인 이방원이 정몽주를 개경 선죽교에서 척살(斥殺)하고, 그 해 8월 5일(음력 7월 17일) 개경의 수창궁(壽昌宮)에서 공양왕에게 왕위를 받은 이성계가 마침내 조선을 건국했다.
# 165	0.004048066128495238	선조의 뒤를 이어 즉위한 광해군은 일본과 두 차례의 전쟁을 치른 후 피폐해진 국토를 정비하기 위해 사림 정치를 배제하고 왕권을 강화하기 위해 노력하였다.
# 214	0.00402244381491124	 1659년(현종 원년)의 1차 논쟁에서는 서인의 주장이, 1674년(숙종 원년)의 2차 논쟁에서는 남인의 주장이 받아들여짐으로써 남인의 정치적 지위가 신장하였다.
# 39	0.003975715598531906	조선은 공식 명칭으로 대조선국(大朝鮮國), 조선국(朝鮮國)이라 하였으며, 주로 대조선국(大朝鮮國)을 어보(御寶), 국서(國書) 등에 사용하였다.
# 205	0.003963922567980338	인조반정으로 정권을 잡은 서인들의 정치력은 근본적으로 지주제에 토대하였기에, 그들의 개혁안은 일정한 한계를 지니는 것이었다.
# 182	0.003945264322940832	고종의 아버지인 흥선군은 대원군이 되어 막강한 권력을 행사하였다.
# 257	0.003945264322940832	 고종의 아버지인 흥선군은 대원군이 되어 막강한 권력을 행사하였다.
# 143	0.003925617924641528	 이리하여 원래 농민 진휼 정책(賑恤政策)에서 발단했던 환곡은 점차 변질되었다.
# 241	0.00391887079930651	 이후 순조 · 헌종(재위 1834~49년) · 철종(재위 1849~63년) 3대에 걸친 안동 김씨와 풍양 조씨 등 외척 세력의 세도 정치가 60여 년 동안 계속되었다.
# 206	0.003916221329127166	 따라서 서인 정권은 기층 사회의 움직임에 미봉적으로 대처할 수밖에 없었다.
# 14	0.003897702115805165	그러나 기존 대신인 훈구와 신진 관료 세력인 사림이 대립하면서 정치는 혼란해졌으며, 이에 따른 전반적인 사회상이 혼탁해졌다.
# 317	0.003884430125693789	 한일 관계#을미사변과 아관파천 문서를 참고하십시오.
# 76	0.003880337552483158	외교면에서는 명(明)에 대해서는 사대정책(事大政策)을 썼다.
# 104	0.0038771965695130854	 성종은《경국대전》의 편찬을 반포함으로써 조선 사회의 기본 통치 방향과 이념을 제시했다.
# 47	0.0038238799123001053	 그러던 중 개국공신들이 권력을 휘두르는 것을 못 본 이방원은 제1차 왕자의 난(1398년)을 일으켜 정권을 장악하다가, 1400년 정종(재위 1398~1400년)의 선위로 집권했다.
# 131	0.0037773056935890437	거듭되는 사화 속에서도 사림들은 서원과 향약을 토대로 발전하여 갔으며, 드디어 선조 때에는 재차 정치무대에 등장하였다.
# 304	0.0037260450220181983	이 부분의 본문은 동학농민운동, 갑오개혁, 및 청일전쟁입니다.
# 244	0.003721803668586885	순조 때에 정권을 잡았던 안동 김씨 세력은 헌종이 즉위하면서 풍양 조씨 집안에게 잠시 권력을 내주었으나 철종이 즉위하면서 다시 정권을 잡아 세도를 떨쳤다.
# 258	0.003716863492956642	 흥선대원군은 실추된 왕권을 회복하고 국가적 위기를 극복하기 위하여 노력하였다.
# 21	0.0037015678863854995	 각 붕당은 학문적, 정치적으로 대립하였으나 상호 견제와 균형을 유지하여 스스로 부패하는 것을 경계했다.
# 30	0.0036642623041253154	 붕당의 근원인 서원을 철폐하고 외척 가문인 안동 김씨 세력들을 축출한다.
# 189	0.0036432867328735114	사림파의 지지를 받고 즉위한 인조는 다시 명나라와의 친선 정책을 펼쳤고, 이에 자극받은 청나라(후금, 여진족)는 1627년(정묘호란)과 1636년(병자호란) 두 번에 걸쳐 조선에 침입하였다.
# 222	0.0036417640903747095	이러한 정치적 동향은 사회 경제적 변화를 바탕으로 일어났다.
# 141	0.0036252649575589245	환곡 제도로 정부는 농민을 상대로 일종의 고리대를 하기도 했다.
# 127	0.0036064004246711885	1567년 왕위에 오른 선조는 이황, 이이 등 사림을 대거 중용하였다.
# 299	0.0035560808064905467	 처음에는 우발적이었으나, 나중에는 대원군의 지시를 받아 민씨 정권에 대항하면서 일본 세력의 배척 운동으로 확대되었다.
# 229	0.003546944367469837	영조의 이러한 노력으로 탕평 정치는 그의 손자인 정조에게로 이어진다.
# 조선(朝鮮, 중세 한국어:  리조조선, 리씨조선, 약칭: [5] 1393년 2월 15일에는 국명을 “조선(朝鮮)”으로 정하였고[6], 1394년에는 한양을 도읍으로 하여 여러 개혁을 단행했다.  성종은 개국 이후의 문물 제도를 정비했다.  15세기 말부터 지방의 사림 세력이 정계에서 세력을 키우기 시작했다.  선조 때에는 마침내 훈구파들이 정계에서 물러나고 사림들이 정계를 장악하게 되었다.  이후 사림들은 '붕당'을 형성하여 조선 정치의 꽃이자 역모 반란죄에 해당될 수 있는 붕당정치를 시행한다. 조선 후기의 정치는 붕당을 중심으로 형성되었다. 1680년의 경신환국으로 서인이 권력을 잡은 뒤 균형이 무너져, 서인은 남인을 철저히 탄압하였다.  그리고 풍양 조씨의 가문의 대표였던 조대비)가 흥선대원군과 결탁하여 흥선대원군의 둘째아들 명복(고종)을 조선 국왕 자리에 올린다. 고종의 아버지인 흥선대원군은 막강한 권력을 행사했다.  또한 무능한 개혁 정책은 조선을 근본적인 근대화로 이끌지 못했다. 1890년대에는 농민 수탈에 대한 저항으로 동학농민운동이 일어났고, 동학농민운동의 진압을 명분으로 조선에 들어온 청나라와 일본의 군대가 충돌하기도 했다.  흔히 조선(朝鮮) 또는 조선 왕조(朝鮮王朝), 이씨 조선(李氏朝鮮), 이왕조(李王朝), 이조(李朝)라고 부르기도 하였다. 조선(1392~1897)의 역사는 크게 전기와 후기로 나누며, 전기를 다시 둘로 나눠 전기와 중기로 보아 전기-중기-후기로 보기도 한다. 1393년에는 국명을 명으로부터 선택받아 조선으로 고치고 1394년에는 개경의 민심이 안 좋아 한양으로 천도하여 여러 개혁을 단행했다.  태종 이방원(재위 1400~18년)은 왕권을 강화하고 임금 중심의 통치 체제를 정비하기 위해 관료 제도를 정비했다. 세종대왕(재위 1418~1450년)은 학문 · 군사 · 과학 · 문화 등 모든 면에서 큰 업적을 이룩하였고 정치는 안정되어갔다.  성종(재위 1469~94년)은 개국 이후의 문물제도를 정비하였다.  15세기 말부터 지방의 사림 세력이 정계에서 세력을 키우기 시작했다.  특히 국호를 정하는 일에서도 내부적으로 국호를 정했으나, 명과의 관계를 고려하여 화령(和寧)과 조선(朝鮮) 중에서 승인을 받았던 일이 있다. 조선에서는 매년 명나라에 진하사, 문안사, 동지사 등을 보냈고 태종 때부터 선조 때까지는 종계변무사를 파견했다.  개국 초기 정도전의 요동정벌 문제로 명나라는 조선의 국왕을 인정하지 않았다.  조선 국왕을 정식 국왕으로 승인한 것은 1401년(태종 1년) 태종 때였다. 또 다른 주변 국가인 일본과 여진에게는 교린 정책(交鄰政策)을 취했다.  이 두 정책은 조선의 근본정책으로서 계속 계승되었다. 두 차례에 걸친 왕자의 난에서 승리해서 왕위에 오른 태종은 왕권을 강화하고 임금 중심의 통치 체제를 정비하기 위해 관료 제도를 정비했다.  또한, 지금의 8도 정책도 태종 때부터 자리 잡은 정책이다. 세조의 손자인 성종은 개국 이후의 문물제도를 정비하였다. 15세기 말부터 지방의 사림 세력이 정계에서 세력을 키우기 시작했다.  선조 때 비로소 훈구파를 몰아내고 조정의 실권을 잡았다.  이때부터 사림은 동인과 서인으로 나뉘어 붕당정치가 시작되었다.  그 이후 사림들 간 자기 일파(일당 전제화)만이 정권을 장악하기 위하여 대대로 대립하니, 이를 당쟁이라 한다. 1545년, 명종이 조선 13대 임금으로 등극하자 어머니 문정왕후가 대왕대비로서 수렴청정했다.  선조는 사림을 통해 자신의 취약한 권력 기반을 강화하고자 하였다. 이 부분의 본문은 임진왜란 및 정유재란입니다. 1592년, 일본을 통일한 도요토미 히데요시(풍신수길)는 20만 병력의 일본군을 조선에 대거 보내어 조선을 침략했다.  조선은 초반 제승방략체제가 제대로 발휘되지 못하였고, 일본군의 신무기인 조총에 크게 고전하였다. 조선 후기의 정치는 붕당을 중심으로 형성되었는데 마침내 서인은 17세기 중반의 예송논쟁에서 남인에게 권력을 넘겨준다.  이어 서인에서 분열된 노론과 소론이 격렬하게 대립하였다.  1873년 흥선대원군이 실각하고 여흥 민씨 정권이 들어서면서 대외정책이 개방되었다.  이어 일본, 미국 등에 문호를 개방하였다.  1890년대에는 농민 수탈에 대한 저항으로 동학농민운동이 일어났고, 동학농민운동의 진압을 명분으로 조선에 들어온 청나라와 일본의 군대가 충돌하였고, 친일적인 갑오개혁이 있었다. 현종과 숙종은 서인(산림, 山林)을 잠시 배척하기도 했으나 결국 남인을 몰아내고 서인과 정치를 하였다.  그러나 외부 세계와의 고립을 초래하여 조선 사회의 낙후를 가속하였다.  이에 따라 조선에서는 청나라를 무조건 배척하지만 말고 이로운 것은 적극적으로 배우자는 북학론(北學論)이 대두하였다. 이 부분의 본문은 붕당입니다.  서인 정권의 위기는 겉으로는 남인 측의 도전으로부터 비롯되었다.  서인이 주도하는 정국에서도 남인은 꾸준히 진출하였다. 남인들은 서인 정권이 추구한 개혁의 부당성과 북벌 운동의 무모함을 지적하면서 예송논쟁(禮訟論爭)을 일으켜 서인들과 정치적으로 대립하였다. 그러나 경신환국에 의하여 1680년 남인이 실각하고 서인 정권이 다시 수립되면서 붕당 사이의 대립양상은 크게 달라져 갔다.  이때, 서인은 아예 남인을 완전히 축출하자는 노론과 남인과의 화해를 주장하는 소론으로 분열되었으며, 두 세력 사이의 대립으로 정국의 반전이 거듭되었다. 정조의 갑작스러운 죽음과 세도정치의 시작은 조선사회 쇠락의 가장 큰 원인이 되었다.  이는 선조 이후 오랫동안 조선 정치권력의 기본 구조였던 붕당정치가 완전히 붕괴되었음을 의미하는 것이기도 하였다.  프랑스는 조선에 대해 사과와 손해 배상, 그리고 통상을 요구하였다. 이로부터 5년 뒤, 이번에는 미국이 조선을 침략하였다.  이에 따라 자연스레 통상 개화론자들이 대두되면서 조선의 대외정책은 조금씩 변하기 시작했다.  일본은 이러한 무력을 배경으로 조선에게 개항을 강요하였다.  이로써, 통상수교 거부정책을 써오던 조선은 부산, 인천, 원산항을 개항하게 되었다.  뒤이어 일본에 신사유람단을, 청나라에 영선사를 파견하였다. 이 부분의 본문은 임오군란 및 갑신정변입니다.  한일 관계#갑오개혁 문서를 참고하십시오. 청일 전쟁에서 승리한 일본은 조선을 청나라로부터 독립시키고, 요동반도를 할양받아 만주 침략의 발판을 마련하였다(→시모노세키 조약). 러시아와 독일, 프랑스의 삼국간섭을 받은 일본은 요동 반도를 잃었고, 남하하는 러시아는 조선에 큰 영향력을 지니게 되었다.  하지만 일본 등의 나라는 조선의 황제국 선포를 인정하지 않고 조선이라 불렀다.  그런데 일본도 조선을 한국이라 부른 면도 있다.

# %%
tr = TextRank()
print('Load...')
from konlpy.tag import Komoran
tagger = Komoran()
stopword = set([('있', 'VV'), ('하', 'VV'), ('되', 'VV') ])
tr.loadSents(RawSentenceReader('wiki_en/chosun.txt'), lambda sent: filter(lambda x:x not in stopword and x[1] in ('NNG', 'NNP', 'VV', 'VA'), tagger.pos(sent)))
print('Build...')
tr.build()
ranks = tr.rank()
for k in sorted(ranks, key=ranks.get, reverse=True)[:100]:
    print("\t".join([str(k), str(ranks[k]), str(tr.dictCount[k])]))
print(tr.summarize(0.2))
# Out:
# Load...
# Build...
# 0	0.09999999999999999	 사군육진 hanja:
# 1	0.09999999999999999	Direct communication between the king and the common people was possible through the sangeon (상언; 上言) written petition system and the gyeokjaeng (격쟁; 擊錚) oral petition system.
# 2	0.09999999999999999	The government officials were ranked in 18 levels, ranging from first senior rank (정1품, 正一品) down to ninth junior rank (종9품, 從九品) based on seniority and promotion, which was achieved through the royal decree based on examination or recommendation.
# 3	0.09999999999999999	The officials of 1st senior rank, 1st junior rank, and 2nd senior rank were addressed with honorific "dae-gam" (대감, 大監) while those of 2nd junior rank and 3rd senior rank were addressed with honorific "yeong-gam" (영감, 令監).
# 4	0.09999999999999999	 The Chief State Councillor (Yeonguijeong, 영의정, 領議政), Left State Councillor (Jwauijeong, 좌의정, 左議政), and Right State Councillor (Uuijeong, 우의정, 右議政) were the highest-ranking officials in the government (All three were of 1st senior rank).
# 5	0.09999999999999999	 They were assisted by Left Minister (Jwachanseong, 좌찬성, 左贊成) and Right Minister (Uichangseong, 우찬성, 右贊成), both of 1st junior rank, and seven lower ranking officials.
# 6	0.09999999999999999	 Each minister (Panseo, 판서, 判書) was of 2nd senior rank and was assisted by deputy minister (Champan, 참판, 參判), who was of 2nd junior rank.
# 7	0.09999999999999999	 It was headed by Chief Scholar (Daejehak·대제학), a part-time post of 2nd senior rank that served concurrently in another high post (such as in State Council), and Deputy Chief Scholar (Bujehak·부제학), a full-time post of 3rd senior rank that actually ran the office.
# 8	0.09999999999999999	County (Gun·군 郡) - There were eighty counties in Joseon, each governed by Gunsu (군수 郡守), a 4th junior rank.
# 9	0.09999999999999999	Hyeon (현 縣) - Large hyeons were governed by Hyeongryeong (현령 縣令) of 5th junior rank while smaller hyeons were governed by Hyeonggam (현감 縣監) of 6th junior rank.
#  사군육진 hanja: Direct communication between the king and the common people was possible through the sangeon (상언; 上言) written petition system and the gyeokjaeng (격쟁; 擊錚) oral petition system.

# %%
tr = TextRank(window=5, coef=1)
print('Load...')
stopword = set([('있', 'VV'), ('하', 'VV'), ('되', 'VV'), ('없', 'VV') ])
tr.load(RawTaggerReader('wiki/chosun.txt'), lambda w: w not in stopword and (w[1] in ('NNG', 'NNP', 'VV', 'VA')))
print('Build...')
tr.build()
kw = tr.extract(0.1)
for k in sorted(kw, key=kw.get, reverse=True):
    print("%s\t%g" % (k, kw[k]))
# Out:
# Load...
# ---------------------------------------------------------------------------
# java.lang.VirtualMachineErrorPyRaisable   Traceback (most recent call last)
# <ipython-input-11-50a1d8bedcd5> in <module>()
#       2 print('Load...')
#       3 stopword = set([('있', 'VV'), ('하', 'VV'), ('되', 'VV'), ('없', 'VV') ])
# ----> 4 tr.load(RawTaggerReader('wiki/chosun.txt'), lambda w: w not in stopword and (w[1] in ('NNG', 'NNP', 'VV', 'VA')))
#       5 print('Build...')
#       6 tr.build()
#
# <ipython-input-8-4a4fb603d28a> in load(self, sentenceIter, wordFilter)
#      83             self.dictNear[a, b] = self.dictNear.get((a, b), 0) + 1
#      84
# ---> 85         for sent in sentenceIter:
#      86             for i, word in enumerate(sent):
#      87                 if wordFilter and not wordFilter(word): continue
#
# <ipython-input-8-4a4fb603d28a> in __iter__(self)
#      60             for s in map(lambda a,b:a+b, ch[::2], ch[1::2]):
#      61                 if not s: continue
# ---> 62                 yield self.tagger.pos(s)
#      63
#      64 class TextRank:
#
# /anaconda3/lib/python3.6/site-packages/konlpy/tag/_komoran.py in pos(self, phrase, flatten)
#      58             result = self.jki.analyzeMorphs(phrase, self.dicpath)
#      59         else:
# ---> 60             result = self.jki.analyzeMorphs3(phrase, self.dicpath).toString()
#      61
#      62         return parse(result, flatten)
#
# java.lang.VirtualMachineErrorPyRaisable: java.lang.OutOfMemoryError: GC overhead limit exceeded

# %%
tr = TextRank(window=5, coef=1)
print('Load...')
stopword = set([('있', 'VV'), ('하', 'VV'), ('되', 'VV'), ('없', 'VV') ])
tr.load(RawTaggerReader('wiki_en/chosun.txt'), lambda w: w not in stopword and (w[1] in ('NNG', 'NNP', 'VV', 'VA')))
print('Build...')
tr.build()
kw = tr.extract(0.1)
for k in sorted(kw, key=kw.get, reverse=True):
    print("%s\t%g" % (k, kw[k]))
# Out:
# Load...
# ---------------------------------------------------------------------------
# java.lang.VirtualMachineErrorPyRaisable   Traceback (most recent call last)
# <ipython-input-12-12b4d8ee673f> in <module>()
#       2 print('Load...')
#       3 stopword = set([('있', 'VV'), ('하', 'VV'), ('되', 'VV'), ('없', 'VV') ])
# ----> 4 tr.load(RawTaggerReader('wiki_en/chosun.txt'), lambda w: w not in stopword and (w[1] in ('NNG', 'NNP', 'VV', 'VA')))
#       5 print('Build...')
#       6 tr.build()
#
# <ipython-input-8-4a4fb603d28a> in load(self, sentenceIter, wordFilter)
#      83             self.dictNear[a, b] = self.dictNear.get((a, b), 0) + 1
#      84
# ---> 85         for sent in sentenceIter:
#      86             for i, word in enumerate(sent):
#      87                 if wordFilter and not wordFilter(word): continue
#
# <ipython-input-8-4a4fb603d28a> in __iter__(self)
#      60             for s in map(lambda a,b:a+b, ch[::2], ch[1::2]):
#      61                 if not s: continue
# ---> 62                 yield self.tagger.pos(s)
#      63
#      64 class TextRank:
#
# /anaconda3/lib/python3.6/site-packages/konlpy/tag/_komoran.py in pos(self, phrase, flatten)
#      58             result = self.jki.analyzeMorphs(phrase, self.dicpath)
#      59         else:
# ---> 60             result = self.jki.analyzeMorphs3(phrase, self.dicpath).toString()
#      61
#      62         return parse(result, flatten)
#
# java.lang.VirtualMachineErrorPyRaisable: java.lang.OutOfMemoryError: GC overhead limit exceeded

# %%
# !pip3 install textrankr
# Out:
# Collecting textrankr
#   Downloading https://files.pythonhosted.org/packages/17/55/f70323e2cd0f93c59aee607c27e55454bcf0f67a2002f584d83464826713/textrankr-0.3.tar.gz
# Requirement already satisfied: setuptools in /anaconda3/lib/python3.6/site-packages (from textrankr) (38.4.0)
# Requirement already satisfied: networkx in /anaconda3/lib/python3.6/site-packages (from textrankr) (1.11)
# Requirement already satisfied: konlpy in /anaconda3/lib/python3.6/site-packages (from textrankr) (0.4.4)
# Requirement already satisfied: jpype1-py3 in /anaconda3/lib/python3.6/site-packages (from textrankr) (0.5.5.2)
# Requirement already satisfied: decorator>=3.4.0 in /anaconda3/lib/python3.6/site-packages (from networkx->textrankr) (4.2.1)
# Building wheels for collected packages: textrankr
#   Running setup.py bdist_wheel for textrankr ... done
#   Stored in directory: /Users/sunu/Library/Caches/pip/wheels/62/ea/be/6d156db74ee32e50a2bad7a6580a18b37ff4ce94dc5a54151e
# Successfully built textrankr
# Installing collected packages: textrankr
# Successfully installed textrankr-0.3

# %% [markdown]
# ## 2nd textrank_korean ...3줄요약

# %%
from __future__ import print_function
from textrankr import TextRank

f = open("wiki/chosun.txt", 'r')
data = f.read()
textrank = TextRank(data)
print(textrank.summarize())
# Out:
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 161
#   warnings.warn('zero out-degree for node %s' % u)
# 조선 후기의 정치는 붕당을 중심으로 형성되었다.
# 조선 후기의 정치는 붕당을 중심으로 형성되었는데 마침내 서인은 17세기 중반의 예송논쟁에서 남인에게 권력을 넘겨준다.
# 1890년대에는 농민 수탈에 대한 저항으로 동학농민운동이 일어났고, 동학농민운동의 진압을 명분으로 조선에 들어온 청나라와 일본의 군대가 충돌하였고, 친일적인 갑오개혁이 있었다.

# %%
from __future__ import print_function
from textrankr import TextRank

f = open("wiki_en/chosun.txt", 'r')
data = f.read()
textrank = TextRank(data)
print(textrank.summarize())
# Out:
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 0
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 2
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 3
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 4
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 5
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 6
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 7
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 8
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 10
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 12
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 13
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 14
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 16
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 17
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 20
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 22
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 23
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 24
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 25
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 27
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 28
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 30
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 31
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 32
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 33
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 34
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 35
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 36
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 37
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 38
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 39
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 40
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 41
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 42
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 43
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 44
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 45
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 46
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 47
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 48
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 50
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 51
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 52
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 53
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 54
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 55
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 56
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 57
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 58
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 62
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 63
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 64
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 65
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 67
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 68
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 69
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 70
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 71
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 72
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 73
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 74
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 75
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 76
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 77
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 78
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 79
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 80
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 81
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 82
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 83
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 84
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 85
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 86
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 87
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 88
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 91
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 92
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 93
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 94
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 95
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 96
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 97
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 99
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 100
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 101
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 102
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 103
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 105
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 106
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 107
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 108
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 109
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 110
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 111
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 112
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 113
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 115
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 116
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 117
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 118
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 119
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 120
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 121
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 123
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 125
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 126
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 127
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 128
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 129
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 130
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 131
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 132
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 133
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 134
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 135
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 136
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 137
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 138
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 139
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 140
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 141
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 142
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 152
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 153
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 154
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 155
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 156
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 157
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 158
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 159
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 160
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 161
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 162
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 164
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 165
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 166
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 167
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 168
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 169
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 170
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 171
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 172
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 173
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 174
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 175
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 176
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 177
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 178
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 179
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 180
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 181
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 182
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 183
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 184
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 185
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 186
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 187
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 188
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 190
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 191
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 192
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 193
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 194
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 196
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 197
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 198
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 199
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 200
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 201
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 202
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 203
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 205
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 208
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 209
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 210
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 211
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 215
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 217
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 218
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 223
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 224
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 225
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 226
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 227
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 228
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 229
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 230
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 231
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 232
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 233
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 234
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 235
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 236
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 237
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 238
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 239
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 241
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 244
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 245
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 246
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 247
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 250
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 253
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 254
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 255
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 256
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 260
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 261
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 262
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 263
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 264
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 266
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 267
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 268
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 269
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 270
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 271
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 272
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 273
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 274
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 275
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 276
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 277
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 278
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 279
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 280
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 281
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 282
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 283
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 284
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 286
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 287
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 288
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 290
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 291
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 292
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 293
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 294
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 296
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 297
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 298
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 299
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 300
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 302
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 304
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 305
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 307
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 308
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 309
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 310
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 311
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 312
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 313
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 314
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 315
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 316
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 318
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 319
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 320
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 321
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 322
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 324
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 325
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 326
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 328
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 330
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 331
#   warnings.warn('zero out-degree for node %s' % u)
# /anaconda3/lib/python3.6/site-packages/networkx/generators/stochastic.py:56: UserWarning: zero out-degree for node 334
#   warnings.warn('zero out-degree for node %s' % u)
# The officials from 1st senior rank to 3rd senior rank wore red robes while those from 3rd junior rank to 6th junior rank wore blue and those below wore green robes.[37].
# It was headed by Chief Scholar (Daejehak·대제학), a part-time post of 2nd senior rank that served concurrently in another high post (such as in State Council), and Deputy Chief Scholar (Bujehak·부제학), a full-time post of 3rd senior rank that actually ran the office.
# There were six royal secretaries (승지), one for each ministry, and all were of 3rd senior rank.

# %% [markdown]
# ## 3rd textrank_english

# %%
# !pip3 install summa
# Out:
# Collecting summa
#   Downloading https://files.pythonhosted.org/packages/b0/2b/b3cdc35b82a1f7d6439d547db47c4ce6e4e2080c20a262352088706da1d1/summa-1.1.0.tar.gz (48kB)
#     100% |████████████████████████████████| 51kB 635kB/s ta 0:00:011
# Requirement already satisfied: scipy>=0.19 in /anaconda3/lib/python3.6/site-packages (from summa) (1.0.0)
# Building wheels for collected packages: summa
#   Running setup.py bdist_wheel for summa ... done
#   Stored in directory: /Users/sunu/Library/Caches/pip/wheels/56/6e/9f/7be3e8cbc8dfa18c1db9eb2ee85e9ee1dcc91e38c4d4e8c969
# Successfully built summa
# Installing collected packages: summa
# Successfully installed summa-1.1.0

# %%
from summa.summarizer import summarize
f = open("wiki_en/chosun.txt", 'r')
data = f.read()

summarize(data, ratio=0.2)

f = open("wiki_en/chosun_min.txt", "w")
f.write(summary)
# Out:
# 'The Joseon dynasty (also transcribed as Chosŏn or Chosun, Korean: 조선; officially the Kingdom of Great Joseon, Korean: 대조선국) was a Korean dynastic kingdom that lasted for approximately five centuries.\nJoseon was the last dynasty of Korea and its longest-ruling Confucian dynasty.\nJoseon consolidated its effective rule over the territory of current Korea and saw the height of classical Korean culture, trade, literature, and science and technology.\nHowever, the dynasty was severely weakened during the late 16th and early 17th centuries, when the Japanese invasions of Korea (1592–98) and the first and second Manchu invasions of 1636 nearly overran the Korean Peninsula, leading to an increasingly harsh isolationist policy, for which the country became known as the "hermit kingdom" in Western literature.\nHowever, whatever power the kingdom recovered during its isolation further waned as the 18th century came to a close, and faced with internal strife, power struggles, international pressure and rebellions at home, the Joseon dynasty declined rapidly in the late 19th century.\nThe Joseon period has left a substantial legacy to modern Korea; much of modern Korean culture, etiquette, norms and societal attitudes towards current issues developed during this period.\nThe modern Korean language, its dialects and Korea\'s majority ethnic group, which refer to themselves as the "Joseon people", derive from the culture and traditions of the Joseon dynasty.\nFollowing the emergence of the Ming dynasty, the royal court in Goryeo split into two conflicting factions: the group led by General Yi (supporting the Ming) and the camp led by General Choe (standing by the Yuan).\nHe later killed King U and his son after a failed restoration and forcibly placed a royal named Yi on the throne (he became Gongyang of Goryeo).\nIn 1392, Yi eliminated Jeong Mong-ju, highly respected leader of a group loyal to Goryeo dynasty, and dethroned King Gongyang, exiling him to Wonju, and before he ascended the throne.\nIn the beginning of his reign, Yi Seonggye, now ruler of Korea, intended to continue use of the name Goryeo for the country he ruled and simply change the royal line of descent to his own, thus maintaining the façade of continuing the 500-year-old Goryeo tradition.\nAfter much internal deliberation, as well as endorsement by the neighboring Ming dynasty\'s emperor, Taejo declared the name of the kingdom to be Joseon, a tribute to the ancient Korean state of Gojoseon.[8] He also moved the capital to Hanyang from Kaesong.\nAlthough Yi Bangwon, Taejo\'s fifth son by Queen Sineui, had contributed most to assisting his father\'s rise to power, the prime minister Jeong Do-jeon and Nam Eun used their influence on King Taejo to name his eighth son (second son of Queen Sindeok) Grand Prince Uian (Yi Bangseok) as crown prince in 1392.\nThis conflict arose largely because Jeong Dojeon, who shaped and laid down ideological, institutional, and legal foundations of the new dynasty more than anyone else, saw Joseon as a kingdom led by ministers appointed by the king while Yi Bangwon wanted to establish the absolute monarchy ruled directly by the king.\nWith Taejo\'s support, Jeong Dojeon kept limiting the royal family\'s power by prohibiting political involvement of princes and attempting to abolish their private armies.\nAfter the sudden death of Queen Sindeok, while King Taejo was still in mourning for his second wife, Yi Bangwon struck first by raiding the palace and killed Jeong Dojeon and his supporters as well as Queen Sindeok\'s two sons (his half-brothers) including the crown prince in 1398.\nThat same year, Yi Bangwon assumed the throne of Joseon at long last as King Taejong, third king of Joseon.\nIn the beginning of Taejong\'s reign, the Grand King Former, Taejo, refused to relinquish the royal seal that signified the legitimacy of any king\'s rule.\nIn 1399, Taejong had played an influential role in scrapping the Dopyeong Assembly, a council of the ol ...

# %% [markdown]
# # 요약된 문장기반 질문생성_한글

# %%
# !python3 quest_ko.py wiki/chosun_min.txt
# Out:
# -----------INPUT TEXT-------------
#
# 조선(朝鮮, 중세 한국어:  리조조선, 리씨조선, 약칭: [5] 1393년 2월 15일에는 국명을 “조선(朝鮮)”으로 정하였고[6], 1394년에는 한양을 도읍으로 하여 여러 개혁을 단행했다.  성종은 개국 이후의 문물 제도를 정비했다.  15세기 말부터 지방의 사림 세력이 정계에서 세력을 키우기 시작했다.  선조 때에는 마침내 훈구파들이 정계에서 물러나고 사림들이 정계를 장악하게 되었다.  이후 사림들은 '붕당'을 형성하여 조선 정치의 꽃이자 역모 반란죄에 해당될 수 있는 붕당정치를 시행한다. 조선 후기의 정치는 붕당을 중심으로 형성되었다. 1680년의 경신환국으로 서인이 권력을 잡은 뒤 균형이 무너져, 서인은 남인을 철저히 탄압하였다.  그리고 풍양 조씨의 가문의 대표였던 조대비)가 흥선대원군과 결탁하여 흥선대원군의 둘째아들 명복(고종)을 조선 국왕 자리에 올린다. 고종의 아버지인 흥선대원군은 막강한 권력을 행사했다.  또한 무능한 개혁 정책은 조선을 근본적인 근대화로 이끌지 못했다. 1890년대에는 농민 수탈에 대한 저항으로 동학농민운동이 일어났고, 동학농민운동의 진압을 명분으로 조선에 들어온 청나라와 일본의 군대가 충돌하기도 했다.  흔히 조선(朝鮮) 또는 조선 왕조(朝鮮王朝), 이씨 조선(李氏朝鮮), 이왕조(李王朝), 이조(李朝)라고 부르기도 하였다. 조선(1392~1897)의 역사는 크게 전기와 후기로 나누며, 전기를 다시 둘로 나눠 전기와 중기로 보아 전기-중기-후기로 보기도 한다. 1393년에는 국명을 명으로부터 선택받아 조선으로 고치고 1394년에는 개경의 민심이 안 좋아 한양으로 천도하여 여러 개혁을 단행했다.  태종 이방원(재위 1400~18년)은 왕권을 강화하고 임금 중심의 통치 체제를 정비하기 위해 관료 제도를 정비했다. 세종대왕(재위 1418~1450년)은 학문 · 군사 · 과학 · 문화 등 모든 면에서 큰 업적을 이룩하였고 정치는 안정되어갔다.  성종(재위 1469~94년)은 개국 이후의 문물제도를 정비하였다.  15세기 말부터 지방의 사림 세력이 정계에서 세력을 키우기 시작했다.  특히 국호를 정하는 일에서도 내부적으로 국호를 정했으나, 명과의 관계를 고려하여 화령(和寧)과 조선(朝鮮) 중에서 승인을 받았던 일이 있다. 조선에서는 매년 명나라에 진하사, 문안사, 동지사 등을 보냈고 태종 때부터 선조 때까지는 종계변무사를 파견했다.  개국 초기 정도전의 요동정벌 문제로 명나라는 조선의 국왕을 인정하지 않았다.  조선 국왕을 정식 국왕으로 승인한 것은 1401년(태종 1년) 태종 때였다. 또 다른 주변 국가인 일본과 여진에게는 교린 정책(交鄰政策)을 취했다.  이 두 정책은 조선의 근본정책으로서 계속 계승되었다. 두 차례에 걸친 왕자의 난에서 승리해서 왕위에 오른 태종은 왕권을 강화하고 임금 중심의 통치 체제를 정비하기 위해 관료 제도를 정비했다.  또한, 지금의 8도 정책도 태종 때부터 자리 잡은 정책이다. 세조의 손자인 성종은 개국 이후의 문물제도를 정비하였다. 15세기 말부터 지방의 사림 세력이 정계에서 세력을 키우기 시작했다.  선조 때 비로소 훈구파를 몰아내고 조정의 실권을 잡았다.  이때부터 사림은 동인과 서인으로 나뉘어 붕당정치가 시작되었다.  그 이후 사림들 간 자기 일파(일당 전제화)만이 정권을 장악하기 위하여 대대로 대립하니, 이를 당쟁이라 한다. 1545년, 명종이 조선 13대 임금으로 등극하자 어머니 문정왕후가 대왕대비로서 수렴청정했다.  선조는 사림을 통해 자신의 취약한 권력 기반을 강화하고자 하였다. 이 부분의 본문은 임진왜란 및 정유재란입니다. 1592년, 일본을 통일한 도요토미 히데요시(풍신수길)는 20만 병력의 일본군을 조선에 대거 보내어 조선을 침략했다.  조선은 초반 제승방략체제가 제대로 발휘되지 못하였고, 일본군의 신무기인 조총에 크게 고전하였다. 조선 후기의 정치는 붕당을 중심으로 형성되었는데 마침내 서인은 17세기 중반의 예송논쟁에서 남인에게 권력을 넘겨준다.  이어 서인에서 분열된 노론과 소론이 격렬하게 대립하였다.  1873년 흥선대원군이 실각하고 여흥 민씨 정권이 들어서면서 대외정책이 개방되었다.  이어 일본, 미국 등에 문호를 개방하였다.  1890년대에는 농민 수탈에 대한 저항으로 동학농민운동이 일어났고, 동학농민운동의 진압을 명분으로 조선에 들어온 청나라와 일본의 군대가 충돌하였고, 친일적인 갑오개혁이 있었다. 현종과 숙종은 서인(산림, 山林)을 잠시 배척하기도 했으나 결국 남인을 몰아내고 서인과 정치를 하였다.  그러나 외부 세계와의 고립을 초래하여 조선 사회의 낙후를 가속하였다.  이에 따라 조선에서는 청나라를 무조건 배척하지만 말고 이로운 것은 적극적으로 배우자는 북학론(北學論)이 대두하였다. 이 부분의 본문은 붕당입니다.  서인 정권의 위기는 겉으로는 남인 측의 도전으로부터 비롯되었다.  서인이 주도하는 정국에서도 남인은 꾸준히 진출하였다. 남인들은 서인 정권이 추구한 개혁의 부당성과 북벌 운동의 무모함을 지적하면서 예송논쟁(禮訟論爭)을 일으켜 서인들과 정치적으로 대립하였다. 그러나 경신환국에 의하여 1680년 남인이 실각하고 서인 정권이 다시 수립되면서 붕당 사이의 대립양상은 크게 달라져 갔다.  이때, 서인은 아예 남인을 완전히 축출하자는 노론과 남인과의 화해를 주장하는 소론으로 분열되었으며, 두 세력 사이의 대립으로 정국의 반전이 거듭되었다. 정조의 갑작스러운 죽음과 세도정치의 시작은 조선사회 쇠락의 가장 큰 원인이 되었다.  이는 선조 이후 오랫동안 조선 정치권력의 기본 구조였던 붕당정치가 완전히 붕괴되었음을 의미하는 것이기도 하였다.  프랑스는 조선에 대해 사과와 손해 배상, 그리고 통상을 요구하였다. 이로부터 5년 뒤, 이번에는 미국이 조선을 침략하였다.  이에 따라 자연스레 통상 개화론자들이 대두되면서 조선의 대외정책은 조금씩 변하기 시작했다.  일본은 이러한 무력을 배경으로 조선에게 개항을 강요하였다.  이로써, 통상수교 거부정책을 써오던 조선은 부산, 인천, 원산항을 개항하게 되었다.  뒤이어 일본에 신사유람단을, 청나라에 영선사를 파견하였다. 이 부분의 본문은 임오군란 및 갑신정변입니다.  한일 관계#갑오개혁 문서를 참고하십시오. 청일 전쟁에서 승리한 일본은 조선을 청나라로부터 독립시키고, 요동반도를 할양받아 만주 침략의 발판을 마련하였다(→시모노세키 조약). 러시아와 독일, 프랑스의 삼국간섭을 받은 일본은 요동 반도를 잃었고, 남하하는 러시아는 조선에 큰 영향력을 지니게 되었다.  하지만 일본 등의 나라는 조선의 황제국 선포를 인정하지 않고 조선이라 불렀다.  그런데 일본도 조선을 한국이라 부른 면도 있다.
#
#
# -----------INPUT END---------------
#
#
#  Question: 무엇 것은 국왕을?
#
#  Question: 무엇 지금의 태종?
#
#  Question: 무엇 조선 명종이?

# %% [markdown]
# # 요약된 문장기반 질문생성_영어

# %%
# !python3 quest.py wiki_en/chosun_min.txt
# Out:
# -----------INPUT TEXT-------------
#
# The Joseon dynasty (also transcribed as Chosŏn or Chosun, Korean: 조선; officially the Kingdom of Great Joseon, Korean: 대조선국) was a Korean dynastic kingdom that lasted for approximately five centuries.
# Joseon was the last dynasty of Korea and its longest-ruling Confucian dynasty.
# Joseon consolidated its effective rule over the territory of current Korea and saw the height of classical Korean culture, trade, literature, and science and technology.
# However, the dynasty was severely weakened during the late 16th and early 17th centuries, when the Japanese invasions of Korea (1592–98) and the first and second Manchu invasions of 1636 nearly overran the Korean Peninsula, leading to an increasingly harsh isolationist policy, for which the country became known as the "hermit kingdom" in Western literature.
# However, whatever power the kingdom recovered during its isolation further waned as the 18th century came to a close, and faced with internal strife, power struggles, international pressure and rebellions at home, the Joseon dynasty declined rapidly in the late 19th century.
# The Joseon period has left a substantial legacy to modern Korea; much of modern Korean culture, etiquette, norms and societal attitudes towards current issues developed during this period.
# The modern Korean language, its dialects and Korea's majority ethnic group, which refer to themselves as the "Joseon people", derive from the culture and traditions of the Joseon dynasty.
# Following the emergence of the Ming dynasty, the royal court in Goryeo split into two conflicting factions: the group led by General Yi (supporting the Ming) and the camp led by General Choe (standing by the Yuan).
# He later killed King U and his son after a failed restoration and forcibly placed a royal named Yi on the throne (he became Gongyang of Goryeo).
# In 1392, Yi eliminated Jeong Mong-ju, highly respected leader of a group loyal to Goryeo dynasty, and dethroned King Gongyang, exiling him to Wonju, and before he ascended the throne.
# In the beginning of his reign, Yi Seonggye, now ruler of Korea, intended to continue use of the name Goryeo for the country he ruled and simply change the royal line of descent to his own, thus maintaining the façade of continuing the 500-year-old Goryeo tradition.
# After much internal deliberation, as well as endorsement by the neighboring Ming dynasty's emperor, Taejo declared the name of the kingdom to be Joseon, a tribute to the ancient Korean state of Gojoseon.[8] He also moved the capital to Hanyang from Kaesong.
# Although Yi Bangwon, Taejo's fifth son by Queen Sineui, had contributed most to assisting his father's rise to power, the prime minister Jeong Do-jeon and Nam Eun used their influence on King Taejo to name his eighth son (second son of Queen Sindeok) Grand Prince Uian (Yi Bangseok) as crown prince in 1392.
# This conflict arose largely because Jeong Dojeon, who shaped and laid down ideological, institutional, and legal foundations of the new dynasty more than anyone else, saw Joseon as a kingdom led by ministers appointed by the king while Yi Bangwon wanted to establish the absolute monarchy ruled directly by the king.
# With Taejo's support, Jeong Dojeon kept limiting the royal family's power by prohibiting political involvement of princes and attempting to abolish their private armies.
# After the sudden death of Queen Sindeok, while King Taejo was still in mourning for his second wife, Yi Bangwon struck first by raiding the palace and killed Jeong Dojeon and his supporters as well as Queen Sindeok's two sons (his half-brothers) including the crown prince in 1398.
# That same year, Yi Bangwon assumed the throne of Joseon at long last as King Taejong, third king of Joseon.
# In the beginning of Taejong's reign, the Grand King Former, Taejo, refused to relinquish the royal seal that signified the legitimacy of any king's rule.
# In 1399, Taejong had played an influential role in scrapping the Dopyeong Assembly, a council of the old government administration that held a monopoly in court power during the waning years of the Goryeo Dynasty, in favor of the State Council of Joseon (Hangul: 의정부 hanja: 議政府), a new branch of central administration that revolved around the king and his edicts.
# Because of such success, Sejong was given the title "Sejong the Great".[14] The most remembered contribution of King Sejong is the creation of Hangul, the Korean alphabet, in 1443; everyday use of Hanja in writing eventually was surpassed by Hangul in the later half of the 20th century.
# In addition to two regents, Princess Gyeonghye also served as Danjong's guardian and, along with the general Kim Jongso, attempted to strengthen royal authority.[15] However, Danjong's uncle, Sejo, gained control of the government and eventually deposed his nephew to become the seventh king of Joseon himself in 1455.
# Jungjong was a fundamentally weak king because of the circumstances that placed him on the throne, but his reign also saw a period of significant reforms led by his minister Jo Gwang-jo, the charismatic leader of sarim.
# According to the Annals of the Joseon Dynasty, it was said that no official dared to receive a bribe or exploit the populace during this time because as Inspector General, he applied law strictly.
# The middle period of Joseon dynasty was marked by a series of intense and bloody power struggles between political factions that weakened the country and large-scale invasions by Japan and Manchu that nearly toppled the dynasty.
# Main article: Political factions in Joseon Dynasty
# The Sarim faction had suffered a series of political defeats during the reigns of Yeonsangun, Jungjong, and Myeongjong, but it gained control of the government during the reign of King Seonjo.
# Factional division in the Joseon court, inability to assess Japanese military capability, and failed attempts at diplomacy led to poor preparation on Joseon's part.
# On such occasions, Nurhaci required help from Gwanghaegun of Joseon (r.1608–1623), putting the Korean state in a difficult position because the Ming court was also requesting assistance.[20] Gwanghaegun tried to maintain neutrality, but most of his officials opposed him for not supporting Ming China, which had saved Joseon during Hideyoshi's invasions.[20]
# Reverting his predecessor's foreign policy, the new king decided to openly support the Ming, but a rebellion led by military commander Yi Gwal erupted in 1624 and wrecked Joseon's military defenses in the north.[20] Even after the rebellion had been suppressed, King Injo had to devote military forces to ensure the stability of the capital, leaving fewer soldiers to defend the northern borders.[20]
# In 1627, a Jurchen army of 30,000 led by Nurhaci's nephew Amin overran Joseon's defenses.[21] After a quick campaign that was assisted by northern yangban who had supported Gwanghaegun, the Jurchens imposed a treaty that forced Joseon to accept "brotherly relations" with the Jurchen kingdom.[22] Because Injo persisted in his anti-Manchu policies, Qing emperor Hong Taiji sent a punitive expedition of 120,000 men to Joseon in 1636.[23] Defeated, King Injo was forced to end his relations with the Ming and recognize the Qing as suzerain instead.[24] Injo's successor Hyojong of Joseon (r.
# Despite reestablishing economic relations by officially entering the imperial Chinese tributary system, Joseon leaders and intellectuals remained resentful of the Manchus, whom they regarded as barbarians.[22] Long after submitting to the Qing, the Joseon court and many Korean intellectuals kept using Ming reign periods, as when a scholar marked 1861 as "the 234th year of Chongzhen."[26]
# Factional conflict grew particularly intense under the reigns of the kings Sukjong and Gyeongjong, with major rapid reversals of the ruling faction, known as *hwanguk* (換局; literally change in the state of affairs), being commonplace.
# The two kings led a second renaissance of the Joseon dynasty.[29][30] Yeongjo's grandson, the enlightened King Jeongjo enacted various reforms throughout his reign, notably establishing Gyujanggak, a royal library in order to improve the cultural and political position of Joseon and to recruit gifted officers to run the nation.
# King Jeongjo had the support of the many Silhak scholars, who supported his regal power.
# King Jeongjo's reign also saw the further growth and development of Joseon's popular culture.
# After the death of King Jeongjo, the Joseon faced difficult external and internal problems.
# These kings had no monarchic authority and could not rule over the government.
# In 1873, King Gojong announced his assumption of royal rule.
# Japan, after the Meiji Restoration, acquired Western military technology, and forced Joseon to sign the Treaty of Ganghwa in 1876, opening three ports to trade and granting the Japanese extraterritoriality.
# Many Koreans despised Japanese and foreign influences over their land and the corrupt oppressive rule of the Joseon Dynasty.
# By May, the peasant army had reached Jeonju, and the Joseon government asked the Qing dynasty government for assistance in ending the revolt.
# Scholars particularly during the Joseon era were touted for expressing allegiance to the king]
# The Joseon court, pressured by encroachment from larger powers, felt the need to reinforce national integrity and declared the Korean Empire, along with the Gwangmu Reform in 1897.
# Technically, 1897 marks the end of the Joseon period, as the official name of the empire was changed; however the Joseon Dynasty would still reign, albeit perturbed by Japan and Russia.
# See also: List of Joseon monarchs, Joseon kings family tree, and Royal titles and styles during the Joseon Period
# The Phoenix Throne of the king of Joseon in Gyeongbokgung
# Royal standard of the King of Joseon
# The natural disasters were thought to be due to the king's failings, and therefore, Joseon kings were very sensitive to their occurrences.
# This allowed even the illiterate members of Joseon society to make a petition to the king.
# The government officials were ranked in 18 levels, ranging from first senior rank (정1품, 正一品) down to ninth junior rank (종9품, 從九品) based on seniority and promotion, which was achieved through the royal decree based on examination or recommendation.
# The Chief State Councillor (Yeonguijeong, 영의정, 領議政), Left State Councillor (Jwauijeong, 좌의정, 左議政), and Right State Councillor (Uuijeong, 우의정, 右議政) were the highest-ranking officials in the government (All three were of 1st senior rank).
# The power of State Council was inversely proportional to the king's power.
# There were periods when it directly controlled Six Ministries, the chief executive body of Joseon government, but it primarily served in advisory role under stronger kings.
# Three Offices, or Samsa (삼사), is a collective name for three offices that functioned as major organ of press and provided checks and balance on the king and the officials.
# The officials who served in these offices tended to be younger and of lower rank compared to other offices but had strong academic reputation and enjoyed special privileges and great prestige (For instance, censors were permitted to drink during working hours because of their function of criticizing the king).
# Office of Inspector General (Saheonbu·사헌부) - It monitored government administration and officials at each level in both central and local governments for corruption, malfeasance, or inefficiency.
# While the primary focus for Office of Inspector General is the government officials and Office of Censors is focused on the king, two offices often performed each other's functions, and there was much overlap.
# Office of Special Advisors (Hongmungwan·홍문관 弘文館) - It oversaw the royal library and served as research institute to study Confucian philosophy and answer the king's questions.
# Its officials took part in the daily lessons called gyeongyeon (경연), in which they discussed history and Confucian philosophy with the king.
# It was headed by Chief Scholar (Daejehak·대제학), a part-time post of 2nd senior rank that served concurrently in another high post (such as in State Council), and Deputy Chief Scholar (Bujehak·부제학), a full-time post of 3rd senior rank that actually ran the office.
# Royal Secretariat (Seungjeongwon, 승정원) served as a liaison between the king and Six Ministries.
# Their primary role was to pass down royal decree to the ministries and submit petitions from the officials and the populace to the king, but they also advised the king and served in other key positions close to the king.
# In particular Chief Royal Secretary (도승지), a liaison to Ministry of Personnel, served the king in the closest proximity of all government official and often enjoyed great power that was derived from the king's favor.
# It chiefly dealt with treason and other serious cases that concerned the king and royal family and served to arrest, investigate, imprison, and carry out sentences against the suspected offenders, who were often government officials.[39]
# The officials of high rank were sent from the central government.
# Sometimes a secret royal inspector (Amhaeng-eosa·암행어사) was appointed by the king to travel incognito and monitor the provincial officials.
#
#
# -----------INPUT END---------------
#  Question: What has Joseon?
#
#  Question: What creation is was?
#
#  Question: What The Joseon expressing?
#
#  Question: What marks Joseon?
#
#  Question: What is Samsa?
#
#  Question: What is Office?

# %% [markdown]
#  질문 : 조선은 무엇입니까?
#
#  질문 : 어떤 창조물이 있었습니까?
#
#  질문 : 조선은 무엇을 표현 하는가?
#
#  질문 : 조선은 무엇인가?
#
#  질문 : Samsa 란 무엇입니까?
#
#  질문 : Office 란 무엇입니까?
